# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
# https://github.com/tshililoa/cleaning-data-checkpoint/blob/main/earthquake_data.csv
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('earthquake_data.csv')

#overview of the dataset
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      782 non-null    object
#  1   magnitude  782 non-null    float64
#  2   date_time  782 non-null    object
#  3   cdi        782 non-null    int64
#  4   mmi        782 non-null    int64
#  5   alert      415 non-null    object
#  6   tsunami    782 non-null    int64
#  7   sig        782 non-null    int64
#  8   net        782 non-null    object
#  9   nst        782 non-null    int64
#  10  dmin       782 non-null    float64
#  11  gap        782 non-null    float64
#  12  magType    782 non-null    object
#  13  depth      782 non-null    float64
#  14  latitude   782 non-null    float64
#  15  longitude  782 non-null    float64
#  16  location   777 non-null    object
#  17  continent  206 non-null    object
#  18  country    484 non-null    object
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# checking for null values.
df.isna()
# True values represent cells with missing values.
# Out:
#      title  magnitude  date_time    cdi    mmi  alert  tsunami    sig    net  \
# 0    False      False      False  False  False  False    False  False  False
# 1    False      False      False  False  False  False    False  False  False
# 2    False      False      False  False  False  False    False  False  False
# 3    False      False      False  False  False  False    False  False  False
# 4    False      False      False  False  False  False    False  False  False
# ..     ...        ...        ...    ...    ...    ...      ...    ...    ...
# 777  False      False      False  False  False   True    False  False  False
# 778  False      False      False  False  False   True    False  False  False
# 779  False      False      False  False  False   True    False  False  False
# 780  False      False      False  False  False   True    False  False  False
# 781  False      False      False  False  False   True    False  False  False
#
# ...

# %%
# checking for the missing data.
df.isnull().sum()
## Missing values: 5 location, 367 alert, 576 continent, and 298 country row entries
# Out:
# title          0
# magnitude      0
# date_time      0
# cdi            0
# mmi            0
# alert        367
# tsunami        0
# sig            0
# net            0
# nst            0
# dmin           0
# gap            0
# magType        0
# depth          0
# latitude       0
# longitude      0
# location       5
# continent    576
# country      298
# dtype: int64

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
## detecting outliers in the dataset ##
df.describe()
boxplot= df.boxplot('magnitude')
plt.show()

# %%
## detecting outliers in the dataset ##
boxplot = df.boxplot('sig')  
plt.show()

# %%
## detecting outliers in the dataset ##
boxplot =df.boxplot('gap')
plt.show()

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
df1 = df.duplicated(keep = False).sum()
print('Number of duplicated rows:', df1)
# Found no duplicated data, therefore no unnecessary duplicate data are present.
# Out:
# Number of duplicated rows: 0

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
## Showing the top 15 rows of the dataset##
df.head(15)
# in the dataset under review, I did not notice any columns with inconsistent data.
# Out:
#                                             title  magnitude  \
# 0    M 7.0 - 18 km SW of Malango, Solomon Islands        7.0
# 1        M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9
# 2                                        M 7.0 -         7.0
# 3             M 7.3 - 205 km ESE of Neiafu, Tonga        7.3
# 4                                        M 6.6 -         6.6
# 5               M 7.0 - south of the Fiji Islands        7.0
# 6               M 6.8 - south of the Fiji Islands        6.8
# 7         M 6.7 - 60 km SSW of Boca Chica, Panama        6.7
# 8          M 6.8 - 55 km SSW of Aguililla, Mexico        6.8
# 9          M 7.6 - 35 km SSW of Aguililla, Mexico        7.6
# 10              M 6.9 - 90 km E of Yujing, Taiwan        6.9
# 11               M 6.5 - 96 km SE of Lugu, Taiwan        6.5
# 12         M 7.0 - 209 km SSE of Isangel, Vanuatu        7.0
# 13  M 7.6 - 70 km E of Kainantu, Papua New Guinea        7.6
# ...

# %%
## Showing the bottom 15 rows of the dataset##
df.tail(15)
# Out:
#                                                  title  magnitude  \
# 767                    M 8.4 - 6 km SSW of Atico, Peru        8.4
# 768    M 6.7 - 128 km SSE of Panguna, Papua New Guinea        6.7
# 769                   M 6.8 - 16 km SSW of Kure, Japan        6.8
# 770              M 6.5 - 41 km SSW of Ambon, Indonesia        6.5
# 771         M 6.8 - 7 km SSE of Longbranch, Washington        6.8
# 772           M 7.1 - 137 km WNW of Ternate, Indonesia        7.1
# 773          M 7.4 - 102 km SSE of Bengkulu, Indonesia        7.4
# 774         M 6.6 - 5 km S of Cojutepeque, El Salvador        6.6
# 775                 M 7.7 - 17 km NW of Bhach?u, India        7.7
# 776           M 6.9 - 59 km WSW of Bengkulu, Indonesia        6.9
# 777  M 7.7 - 28 km SSW of Puerto El Triunfo, El Sal...        7.7
# 778              M 6.9 - 47 km S of Old Harbor, Alaska        6.9
# 779             M 7.1 - 16 km NE of Port-Olry, Vanuatu        7.1
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# -- I did  not find any duplicated data.
# -- Found missing data : 367 alert, 576 continent, and 298 country row entries.
# -- There are outliers in the magnitude, sig and gap columns, as show in the graphs above. There is no action taken since these do not affect the analysis of my data.
# -- There were no inconsistent data to mention that affect my dataset and analysis of it.
#
# 2. Did the process of cleaning your data give you new insights into your dataset?
# -- Apart from the missing country and continent data (because of where the earthquakes were located, my dataset is very clean and easy to work through.
#
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# -- The fact that there are missing values for country and continent means that these columns cannot to be fully used in vizualization.
